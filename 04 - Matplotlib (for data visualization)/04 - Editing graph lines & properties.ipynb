# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# # Plot apperance:

# %%
import numpy as np

x = np.linspace(0,5,11)    
y = x ** 2

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])    
 
axes.plot(x, y, color='#FF8C00')      # RGB Hex code

# %% [markdown]
# # Linewidth, line styles, colors with parameters & marker styles
#
# To change the line width, we can use the `linewidth` or `lw` keyword argument. The line style can be selected using the `linestyle` or `ls` keyword arguments.
#
# For linestyle supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'
#
# We can also define colors by their names or RGB hex codes and optionally provide an alpha value using the `color` and `alpha` keyword arguments. Alpha indicates opacity.

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])    
 
axes.plot(x, y, color='#FF8C00', lw='5', ls='-.', alpha=0.5)     # half-transparant

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
len(x)
# Out:
# 11

# %% [markdown]
# ### Marker and marker styles syntax:
#
# - `marker`:  possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
# - `markersize`: name reflects all
# - `markerfacecolor`: name reflects all
# - `markeredgecolor`: name reflects all
# - `markeredgewidth`: name reflects all

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])    
 
axes.plot(x, y, color='#FF8C00', lw='2', alpha=0.9, marker='o', markersize ='20', markerfacecolor='purple',
          markeredgewidth=3, markeredgecolor='green')     # marker and marker styles

# %%
fig, ax = plt.subplots(figsize=(12,6))



# RED COLOUR LINES



ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)



# GREEN COLOUR LINES



# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')



# BLACK COLOUR LINES



# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...



#BLUE COLOUR LINES



# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')



# PURPLE COLOUR LINES



# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# # Plot range:
#
# We can configure the ranges of the axes using the `set_ylim` and `set_xlim` by setting up the **[lower bound, upper bound]** methods in the axis object, or `axis('tight')` for automatically getting "tightly fitted" axes ranges:

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=2,ls='--')

ax.set_xlim([0,1])    # Lowerbound = 0, upperbound = 1
ax.set_ylim([0,2])    # Lowerbound = 0, upperbound = 2

# Since there are only 11 points so it looks as a bunch of straight lines as we ZOOM IN here
# Out:
# (0.0, 2.0)

# %% [markdown]
# # Special Plot types:
#
# There are many specialized plots we can create, such as barplots, histograms, scatter plots, and much more. Most of these type of plots we will actually create using ***seaborn***, a statistical plotting library for Python.

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([11.,  9., 12., 10.,  5.,  9., 15., 11., 12.,  6.]),
#  array([ 12. , 110.3, 208.6, 306.9, 405.2, 503.5, 601.8, 700.1, 798.4,
#         896.7, 995. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# # Other good resources:
#
# * http://www.matplotlib.org - The project web page for matplotlib.
# * https://github.com/matplotlib/matplotlib - The source code for matplotlib.
# * http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots matplotlib can create.
# * http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
# * http://scipy-lectures.github.io/matplotlib/matplotlib.html - Another good matplotlib reference.
